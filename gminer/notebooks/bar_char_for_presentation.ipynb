# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

objects = ("HAAD","AFR", "AMR", "EUR","EAS", "SAS", "gnomAD")
y_pos = np.arange(len(objects))
performance = [0.2306, 0.218,0.009,0.002,0,0,0.014]

plt.bar(objects, performance, align='center', alpha=0.5)

plt.ylabel('MAF')
plt.title('CYP2D6 *17 Allele frequencies')

#plt.show()
plt.savefig("2D6_17_freq_chart.png")
