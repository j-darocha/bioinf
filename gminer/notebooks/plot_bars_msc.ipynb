# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt; plt.rcdefaults()


objects = ('Python', 'C++', 'Java', 'Perl', 'Scala', 'Lisp')
y_pos = np.arange(len(objects))
performance = [10,8,6,4,2,1]

plt.barh(y_pos, performance, align='center', alpha=0.5)
plt.yticks(y_pos, objects)
plt.xlabel('Usage')
plt.title('Programming language usage')

plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt; plt.rcdefaults()
from  matplotlib.colors import Normalize  
from matplotlib.cm import get_cmap

df = pd.read_csv("key_variants_to_plot_DPYD_new_corrected.csv", sep = ",")
df= df.drop(columns=['p value', "*"])
df = df.T
x = list(df.index)[1:]
y = [ float(x) for x in  list(df[0][1:] )  ]

cmap = get_cmap('viridis')
normalize = Normalize(vmin=min(y), vmax=max(y))
colors = [cmap(normalize(value)) for value in y]
plt.bar(x, y, color=colors )
# Out:
# <BarContainer object of 13 artists>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt; plt.rcdefaults()
from  matplotlib.colors import Normalize  
from matplotlib.cm import get_cmap

df = pd.read_csv("key_variants_to_plot_DPYD.csv", sep = ",")
df= df.drop(columns=['p value', "*"])
df = df.T

x = list(df.index)[1:]
y = [ float(x) for x in  list(df[0][1:] )  ]

plt.rcParams["figure.figsize"] = [13, 6]

x_colours = ["#0000ffff","#ff4100ff","#0000ffff","#ff4100ff","#0000ffff",
             "#ff4100ff","#0000ffff","#ff4100ff","#0000ffff","#ff4100ff","#0000ffff"]
plt.ylim({0,1})

cmap = get_cmap('viridis')
normalize = Normalize(vmin=min(y), vmax=max(y))
colors = [cmap(normalize(value)) for value in y]
plt.bar(x, y, color=x_colours )
# Out:
# <BarContainer object of 13 artists>

# %%
colors
x_colours = ["#0000ffff","#ff4100ff","#0000ffff","#ff4100ff","#0000ffff","#ff4100ff","#0000ffff","#ff4100ff","#0000ffff","#ff4100ff","#0000ffff"]

# %%
plot_bars_msc.ipynb

# %%
def plotbars(idx, dataframe):
    x = list(dataframe.index)[1:]
    y = [ float(x) for x in  list(df[idx][1:] )  ]
    return x, y
fig, axs = plt.subplots(2, 1, tight_layout = True)

for axidnx, colindex in zip(range(0, 2), [0, 1]):
    print(axidnx,colindex )
    x1,y1 = plotbars(colindex,df)
    axs[axidnx].bar(x1, y1, color = ["#000080ff","#0000ffff","#b60dffff","#07c1c4ff","#07c472ff","#00ff00ff","#008000ff","#003c00ff","#f2ff00ff","#800000ff","#ff0000ff","#ff00ffff","#ff7f00ff"])
    axs[axidnx].set_ylim([0,1])
    plt.ylabel('Freq.')


    
    

#x1,y1 = plotbars(1,df)
#axs[0].bar(x1, y1)

#x2,y2 = plotbars(2,df)
#axs[1].bar(x2, y2)
plt.ylabel('Freq.')
plt.ylim([0,1])
plt.rcParams["figure.figsize"] = [20, 10]
# Out:
# 0 0
# 1 1
# /home/jorge/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:2369: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
def plotbars(idx, dataframe):
    x = list(dataframe.index)[1:]
    y = [ float(x) for x in  list(df[idx][1:] )  ]
    return x, y
plt.rcParams["figure.figsize"] = [15, 25]

fig, axs = plt.subplots(4, 1,)


for axidnx, colindex in zip(range(0, 4), range(0,4)):
    print(axidnx,colindex )
    x1,y1 = plotbars(colindex,df,)
    axs[axidnx].bar(x1, y1, color = ["#000080ff","#0000ffff","#b60dffff","#07c1c4ff","#07c472ff","#00ff00ff","#008000ff","#003c00ff","#f2ff00ff","#800000ff","#ff0000ff","#ff00ffff","#ff7f00ff"])
    axs[axidnx].set_ylim([0,0.15])


    
    

#x1,y1 = plotbars(1,df)
#axs[0].bar(x1, y1)

#x2,y2 = plotbars(2,df)
#axs[1].bar(x2, y2)

font = {'family' : 'arial',
        'weight' : 'bold',
        'size'   : 12}

plt.rc('font', **font)

#plt.savefig('DPYD_Cool_Vars.svg')
# Out:
# 0 0
# 1 1
# 2 2
# 3 3

# %%
def plotbars(idx, dataframe):
    x = list(dataframe.index)[1:]
    y = [ float(x) for x in  list(df[idx][1:] )  ]
    return x, y
plt.rcParams["figure.figsize"] = [15, 25]

fig, axs = plt.subplots(6, 1,)

for axidnx, colindex in zip(range(0, 6), range(12,18)):
    print(axidnx,colindex )
    x1,y1 = plotbars(colindex,df)
    axs[axidnx].bar(x1, y1, color = ["#000080ff","#0000ffff","#b60dffff","#07c1c4ff","#07c472ff","#00ff00ff","#008000ff","#003c00ff","#f2ff00ff","#800000ff","#ff0000ff","#ff00ffff","#ff7f00ff"])
    axs[axidnx].set_ylim([0,1])


    
    

#x1,y1 = plotbars(1,df)
#axs[0].bar(x1, y1)

#x2,y2 = plotbars(2,df)
#axs[1].bar(x2, y2)
font = {'family' : 'arial',
        'weight' : 'bold',
        'size'   : 15}

plt.rc('font', **font)

plt.ylim([0,1])
#plt.savefig('Well_Charact_variants_fig.svg')
# Out:
# 0 12
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 12
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-05e8a504e45f> in <module>
# ...
